# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/raw/data.csv')

# %%
df.head()
# Out:
#           Income  Age  Dependents     Occupation City_Tier          Rent  \
# 0   44637.249636   49           0  Self_Employed    Tier_1  13391.174891
# 1   26858.596592   34           2        Retired    Tier_2   5371.719318
# 2   50367.605084   35           1        Student    Tier_3   7555.140763
# 3  101455.600247   21           0  Self_Employed    Tier_3  15218.340037
# 4   24875.283548   52           4   Professional    Tier_2   4975.056710
#
#    Loan_Repayment    Insurance     Groceries    Transport  ...  \
# 0        0.000000  2206.490129   6658.768341  2636.970696  ...
# 1        0.000000   869.522617   2818.444460  1543.018778  ...
# 2     4612.103386  2201.800050   6313.222081  3221.396403  ...
# 3     6809.441427  4889.418087  14690.149363  7106.130005  ...
# 4     3112.609398   635.907170   3034.329665  1276.155163  ...
#
#    Desired_Savings  Disposable_Income  Potential_Savings_Groceries  \
# 0      6200.537192       11265.627707                  1685.696222
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Income                           20000 non-null  float64
#  1   Age                              20000 non-null  int64
#  2   Dependents                       20000 non-null  int64
#  3   Occupation                       20000 non-null  object
#  4   City_Tier                        20000 non-null  object
#  5   Rent                             20000 non-null  float64
#  6   Loan_Repayment                   20000 non-null  float64
#  7   Insurance                        20000 non-null  float64
#  8   Groceries                        20000 non-null  float64
#  9   Transport                        20000 non-null  float64
#  10  Eating_Out                       20000 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                                    count          mean           std  \
# Income                           20000.0  41585.496104  40014.540538
# Age                              20000.0     41.031450     13.578725
# Dependents                       20000.0      1.995950      1.417616
# Rent                             20000.0   9115.494629   9254.228188
# Loan_Repayment                   20000.0   2049.800292   4281.789941
# Insurance                        20000.0   1455.028761   1492.938435
# Groceries                        20000.0   5205.667493   5035.953689
# Transport                        20000.0   2704.466685   2666.345648
# Eating_Out                       20000.0   1461.856982   1481.660811
# Entertainment                    20000.0   1448.853658   1489.019270
# Utilities                        20000.0   2504.976953   2522.981880
# Healthcare                       20000.0   1663.081794   1628.163024
# Education                        20000.0   2498.348422   3098.438166
# ...

# %%
plt.figure(figsize=(15, 8), dpi=100)
sns.histplot(df['Income'], bins=50, kde=True)
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(15, 8),dpi=300)
sns.boxplot(x='Income', data=df,)
plt.title('Income Boxplot')
plt.xlabel('Income')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.histplot(df['Age'], bins=50, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.histplot(df['Desired_Savings'], bins=50, kde=True)
plt.title('Desired Savings Distribution')
plt.xlabel('Desired Savings')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='Desired_Savings', data=df)
plt.title('Desired Savings Boxplot')
plt.xlabel('Desired Savings')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.histplot(df['Disposable_Income'], bins=50, kde=True)
plt.title('Disposable Income Distribution')
plt.xlabel('Disposable Income')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='Disposable_Income', data=df)
plt.title('Disposable Income Boxplot')
plt.xlabel('Disposable Income')
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(16, 10),dpi=300)
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
potential_savings_cols = ['Potential_Savings_Groceries', 'Potential_Savings_Transport', 'Potential_Savings_Eating_Out', 'Potential_Savings_Entertainment', 'Potential_Savings_Utilities',
                          'Potential_Savings_Healthcare', 'Potential_Savings_Education', 'Potential_Savings_Miscellaneous']

df['Total_Potential_Savings'] = df[potential_savings_cols].sum(axis=1)

# %%
df.drop(columns=potential_savings_cols, inplace=True)

# %%
df.head()
# Out:
#           Income  Age  Dependents     Occupation City_Tier          Rent  \
# 0   44637.249636   49           0  Self_Employed    Tier_1  13391.174891
# 1   26858.596592   34           2        Retired    Tier_2   5371.719318
# 2   50367.605084   35           1        Student    Tier_3   7555.140763
# 3  101455.600247   21           0  Self_Employed    Tier_3  15218.340037
# 4   24875.283548   52           4   Professional    Tier_2   4975.056710
#
#    Loan_Repayment    Insurance     Groceries    Transport   Eating_Out  \
# 0        0.000000  2206.490129   6658.768341  2636.970696  1651.801726
# 1        0.000000   869.522617   2818.444460  1543.018778   649.378103
# 2     4612.103386  2201.800050   6313.222081  3221.396403  1513.814376
# 3     6809.441427  4889.418087  14690.149363  7106.130005  5040.249158
# 4     3112.609398   635.907170   3034.329665  1276.155163   692.827225
#
#    Entertainment    Utilities   Healthcare    Education  Miscellaneous  \
# ...

# %%
numeric_df1 = df.select_dtypes(include=['number'])
plt.figure(figsize=(16, 10), dpi=300)
sns.heatmap(numeric_df1.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap After Adding Total Potential Savings')
plt.show()

# %%
plt.figure(figsize=(15, 8),dpi=300)
sns.scatterplot(x='Desired_Savings', y='Total_Potential_Savings', data=df)
plt.title('Desired Savings vs Total Potential Savings')
plt.xlabel('Desired Savings')
plt.ylabel('Total Potential Savings')
plt.show()
